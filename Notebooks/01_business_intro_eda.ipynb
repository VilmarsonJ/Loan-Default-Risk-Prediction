# %% [markdown]
# # **Akademi Education - Data Science & IA - Cohorte (2025)**
# ---
# - ### **Instructeurs :**  Wedter Jerome & Geovany Batista Polo Laguerre
#
# - ### **Phase 5 :** Capstone Project DE SCIENCE DES DONNÉES
# - ### **Noms des étudiants du groupe :** Vilmarson JULES & Rodolphe Charles
# - ### **LinkedIn:** [Vilmarson JULES](https://www.linkedin.com/in/jules-vilmarson-2a68a5294/) | [Rodolphe CHARLES](https://www.linkedin.com/in/rodolphe-charles-81b75924b?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app)
# - ### **Noms des instructeurs :** Wedter JEROME et Geovany Batista Polo LAGUERRE
# - ### **Rythme d’apprentissage :** Autonome
# - ### **Date de soutenance :** 28 octobre 2025
# > - ### **Lien GitHub du projet :** [Prédiction du Risque de Défaut de Prêt](https://github.com/VilmarsonJ/Loan-Default-Risk-Prediction.git)
# ---

# %% [markdown]
# # **Prédiction du Risque de Défaut de Prêt pour les Institutions Financieres**
#
# ---
# ### ***Une étude basée sur les données pour évaluer le risque de crédit et optimiser les décisions de financement***
#
# ![photo](../Images/image12.webp)
#
# > #### **Akademi Education – Octorbre 2025**

# %% [markdown]
# ## **Vue d’Ensemble du Projet**
# ---
#
# Les défauts de remboursement constituent un **défi majeur pour les banques**, affectant **la rentabilité**, **la stabilité financière** et **l’accès au crédit**. Évaluer efficacement quels candidats sont susceptibles de faire défaut est essentiel pour **réduire les risques** et **prendre des décisions de prêt éclairées**.
#
# Ce projet utilise le **machine learning** pour prédire la probabilité qu’un emprunteur ne rembourse pas son prêt. En exploitant les données historiques de prêts et les caractéristiques des clients, le modèle identifie les **schémas et facteurs de risque** liés aux défauts.
#
#
#
# - ### ***Les objectifs principaux de ce projet sont :***
#
# #### **1. Prédire le risque de défaut de prêt** afin de gérer de manière proactive les emprunteurs à haut risque.
# #### **2. Soutenir les décisions stratégiques de prêt** grâce à des **insights exploitables**.
# #### **3. Réduire les prêts non performants (NPL)** et améliorer la **stabilité financière globale**.
# #### **4. Améliorer les processus d’évaluation du crédit** par une analyse **basée sur les données**.
#
# En combinant **données historiques et analyses avancées**, cette étude démontre comment la **modélisation prédictive** peut **guider de meilleures décisions de crédit**, **atténuer le risque financier** et **favoriser des pratiques de prêt responsables**.

# %% [markdown]
# ## **Brève Description**
# ---
#
# Cette étude utilise des **modèles de machine learning** pour prédire le risque de défaut de remboursement des prêts. En analysant les **demandes de prêt historiques** et les **profils des clients**, les modèles permettent d’identifier les **emprunteurs potentiellement à haut risque**, offrant ainsi aux institutions financières la possibilité de **prendre des décisions de crédit basées sur les données**.
#
# Les insights issus de cette analyse contribuent à **réduire les prêts non performants**, **optimiser les stratégies de prêt** et **renforcer la stabilité financière globale**, démontrant l’impact concret de l’analytics prédictive dans le secteur bancaire.

# %% [markdown]
# ## **Business Problem (Problématique du Crédit)**
# ---
# ![photo](../Images/image27.jpg)
#
#
# Le défaut de remboursement des prêts reste l’un des défis les plus critiques pour les institutions financières dans le monde. Lorsqu’un emprunteur ne rembourse pas son prêt, les banques subissent des **pertes financières directes**, voient leurs **prêts non performants (NPL) augmenter**, et peuvent faire face à des **risques de liquidité**.
#
# De plus, un taux élevé de défaut peut **saper la confiance dans le secteur bancaire**, limiter **l’accès au crédit pour d’autres clients**, et compliquer la **conformité réglementaire**. Ce problème est particulièrement marqué dans les marchés émergents, où l’accès au crédit fiable est limité et l’écosystème financier est plus sensible aux défauts.
#
# **Problème central : Comment les institutions financières peuvent-elles identifier de manière proactive les emprunteurs présentant un risque élevé de défaut ?**
#
# Résoudre ce problème permet aux banques et prêteurs de :
# - Prendre des **décisions de prêt basées sur les données**.
# - Concevoir des **interventions ciblées** pour les emprunteurs à risque.
# - Réduire les **pertes financières** et **stabiliser les portefeuilles de prêts**.
# - Soutenir les initiatives de **gestion stratégique et réglementaire du risque**.
#
# > Ce projet aborde cette problématique en exploitant des **données historiques sur les prêts et les clients** avec des **modèles de machine learning**, transformant des patterns complexes en insights exploitables pour **prévenir les défauts avant qu’ils ne surviennent**.

# %% [markdown]
# ## **The Data**
# ---
#
# Le jeu de données utilisé dans ce projet provient du **[Loan Default Prediction Challenge](https://www.kaggle.com/datasets/nikhil1e9/loan-default?)** sur Kaggle, basé à l’origine sur l’étude de cas **Loan Default Prediction de Coursera**. Il représente des **données financières réelles de prêts** provenant de banques et d’institutions de crédit accordant des prêts aux particuliers et aux entreprises.
#
# ![photo](../Images/image01.png)
#
#
# Ces données contiennent des informations essentielles sur les emprunteurs et les prêts, incluant **les revenus, les types d’emploi, les montants de prêt, l’historique de crédit et les résultats de remboursement**, offrant ainsi une vision complète des facteurs influençant le **risque de défaut**.
#
# Ce jeu de données a été choisi car il reflète **les véritables défis de gestion du risque de crédit** rencontrés par le secteur bancaire. Il constitue une base solide pour construire et évaluer des **modèles de machine learning** visant à **prévoir les défauts, réduire les pertes financières**, et **soutenir des décisions de prêt basées sur les données**.

# %% [markdown]
# ## **Methods**
#
# ---
#
# Dans ce projet, nous adoptons une approche de **Predictive Analytics** centrée sur la **classification binaire** pour évaluer le risque de défaut de prêt. L’objectif est d’aider les institutions financières à **prendre des décisions de crédit basées sur les données, réduire les pertes financières et améliorer la stabilité des portefeuilles**, tant au niveau mondial que dans des contextes comme Haïti, où l’accès au crédit fiable est limité et les défauts peuvent fortement impacter la stabilité financière.
#
# ***Nous nous appuyons sur un écosystème Python robuste pour la data science, incluant :***
# - **Data manipulation & analysis :** `pandas`, `numpy`
# - **Visualization :** `matplotlib`, `seaborn`
# - **Machine learning :** `scikit-learn`, `xgboost`, `lightgbm`
# - **Environment & version control :** Git, GitHub, Jupyter Notebook
#
# L’analyse sera effectuée **localement** sur une machine performante, et toutes les données sont stockées dans notre **local repository**, garantissant la reproductibilité et le contrôle complet.
#
#
# ### I – Data Understanding
# - Importer et explorer le dataset pour comprendre sa **structure, ses features et la variable cible (`Default`)**.
# - Générer des **statistiques descriptives** pour identifier les distributions des features et les patterns liés au risque de prêt.
# - Vérifier les **valeurs manquantes, incohérences et anomalies** pour garantir des entrées fiables pour le modeling.
# - Visualiser les relations entre les features et la cible pour guider la **feature engineering** future.
# - Souligner les **implications pour Haïti**, par exemple les patterns liés aux revenus ou types d’emploi pouvant refléter les défis locaux du crédit.
#
#
# ### II – Data Cleaning
# - Traiter les **valeurs manquantes, les entrées incorrectes et les doublons**.
# - Assurer des **types de données cohérents** pour toutes les colonnes.
# - Préparer le dataset pour l’**exploratory analysis et la feature engineering**, tout en conservant la signification business.
#
#
# ### III – Exploratory Data Analysis (EDA)
# - Visualiser les distributions des **features numériques et catégoriques**.
# - Identifier les **corrélations et patterns** pouvant indiquer des facteurs de risque.
# - Traduire les résultats en **insights business** compréhensibles par les parties prenantes non techniques, en mettant en avant des tendances globales et locales (Haïti).
#
#
# ### IV – Data Preprocessing & Feature Engineering
# - Effectuer la **categorical encoding** (ex. one-hot encoding) pour compatibilité avec les modèles ML.
# - Scaler ou normaliser les features numériques si nécessaire.
# - Créer des **features dérivées** augmentant la puissance prédictive et reflétant la logique métier, comme les **Debt-to-Income Ratios**, les ratios de durée de prêt, ou des **risk flags** pertinents pour le contexte local.
#
#
# ### V – Modeling
# - Entraîner et comparer **plusieurs algorithmes de classification**, incluant :
#   - **Logistic Regression** – modèle interprétable de base
#   - **Random Forest** – capture les relations non linéaires et interactions
#   - **XGBoost & LightGBM** – méthodes d’ensemble performantes pour la précision
# - Utiliser la **cross-validation et l’hyperparameter tuning** pour optimiser la performance des modèles.
# - Évaluer l’impact des modèles à la fois pour un **contexte global** et pour des marchés locaux comme Haïti, où mal classifier des emprunteurs à risque peut avoir de lourdes conséquences.
#
#
# ### VI – Model Evaluation
# - Évaluer les modèles avec **accuracy, precision, recall, F1-score et ROC-AUC**.
# - Traduire les métriques dans le **contexte business** :
#   - Le **recall** indique la proportion d’emprunteurs à haut risque correctement identifiés.
#   - La **precision** reflète la confiance dans les prédictions de défaut.
# - Utiliser ces évaluations pour **sélectionner le modèle le plus performant** pour des prédictions actionnables.
#
#
# ### VII – Insights & Interpretation
# - Identifier les **facteurs clés de défaut de prêt** et fournir des **risk scores quantitatifs** pour chaque emprunteur.
# - Recommander des **interventions ciblées** et des stratégies pour réduire les défauts.
# - Communiquer les résultats de manière **claire et exploitable**, en considérant à la fois les **institutions financières globales** et les marchés locaux comme Haïti, pour améliorer la prise de décision en matière de crédit et la stabilité des portefeuilles.

# %% [markdown]
# ## **Business Understanding**
# ---
#
# Les défauts de paiement représentent un défi majeur pour les institutions financières, impactant la **rentabilité, le risque de crédit et la stabilité financière**. L’objectif de cette étude est la **prévision du risque de défaut de prêt**, où l’analytique prédictive peut transformer les décisions de prêt, permettant une **gestion proactive des risques** et une meilleure allocation des ressources.
#
# Cette étude se concentre sur le contexte des ***services bancaires et financiers***, avec des applications dans **l’évaluation du risque de crédit, la stratégie de prêt et la conformité réglementaire**.
#
# #### ***Le public cible principal comprend :***
# - **Banques et institutions financières :** optimiser les prêts et réduire les pertes.
# - **Banques centrales et régulateurs :** surveiller et gérer le risque systémique.
# - **Fintech et prêteurs :** mettre en œuvre des processus d’approbation de crédit basés sur les données.
#
# En appliquant des **modèles de machine learning avancés**, cette étude traduit des données complexes en **indicateurs quantitatifs de risque**. Cela permet aux parties prenantes de **détecter proactivement les emprunteurs à haut risque**, de cibler plus efficacement les interventions et de prendre des **décisions stratégiques basées sur des preuves**.
#
# #### ***L’impact concret de ce projet est significatif :***
# **1.** **Réduire les prêts non performants (NPLs)** et minimiser les pertes financières.
# **2.** Fournir des **scores de risque pour chaque emprunteur** afin de guider les décisions de prêt.
# **3.** Permettre des **interventions ciblées** pour les emprunteurs à risque de défaut.
# **4.** Soutenir les **rapports réglementaires** et renforcer la **stabilité financière globale**.
#
# >La **motivation** de ce projet est de montrer comment la **data science peut transformer les pratiques de prêt traditionnelles**, améliorer la qualité des décisions de crédit et apporter une **valeur business tangible** aux institutions financières, régulateurs et prêteurs.

# %% [markdown]
# ## **Data Understanding**
# ---
#
# Avant de construire des modèles prédictifs, il est essentiel de **comprendre et explorer le jeu de données**. Cette section se concentre sur l’examen de la structure, des variables et des tendances présentes, afin d’identifier les **facteurs clés influençant les défauts de remboursement**.
#
# Grâce à des **statistiques descriptives, des visualisations et des inspections initiales**, nous cherchons à :
# - Comprendre la **distribution des variables numériques et catégorielles**.
# - Identifier les **valeurs manquantes, incohérences ou anomalies**.
# - Explorer les **relations entre les variables et la cible (`Default`)**.
# - Obtenir des **insights business** pouvant orienter l’ingénierie des features et le choix des modèles.
#
# Cette étape permet de transformer des données brutes en **connaissances exploitables**, préparant ainsi le terrain pour le **nettoyage, le prétraitement et la modélisation prédictive**, tout en gardant un lien clair avec le **contexte métier**.

# %% [markdown]
# #### Importation des Bibliothèques et Outils necessaires pour l'EDA

# %%
#### Import Libraries and Tools for Loan Default Risk Prediction

# -----------------------------
# Data Handling
# -----------------------------
import pandas as pd       # For data manipulation
import numpy as np        # For numerical operations
import math               # For mathematical operations if needed
import os                 # For file system operations

# -----------------------------
# Data Visualization
# -----------------------------
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib.patches import Patch

sns.set(style="whitegrid")
plt.style.use("seaborn-darkgrid")

# Miscellaneous
# -----------------------------
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Charger le jeu de données de manière sûre et explicite
#
# Dans cette section, nous importons le jeu de données principal à partir du dossier *Data*.
# L’objectif est d’assurer un chargement correct et reproductible, en respectant la structure du projet et en facilitant la réutilisation du code sur d’autres environnements.

# %%
# -----------------------------
# Load the dataset safely and clearly
# -----------------------------

# Build the relative path from the current notebook to the CSV
data_path = os.path.join("..", "Data/raw", "Loan_default.csv")

# Check if file exists before loading
if os.path.exists(data_path):
    loan = pd.read_csv(data_path)
    # print(f"✅ Dataset successfully loaded! Shape: {loan.shape}")
else:
    raise FileNotFoundError(f"❌ Dataset not found at: {data_path}")

# %% [markdown]
# Le jeu de données contient **255 347 dossiers de prêts** répartis sur **18 variables**, offrant un mélange riche d'attributs démographiques, financiers et comportementaux pour chaque demandeur.
# Chaque observation représente une **demande de prêt individuelle**, avec la variable cible **`Default`** indiquant si l’emprunteur a remboursé avec succès ou a fait défaut.

# %%
# The first five rows of the loan Dataframe
loan.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# ...

# %%
# The global info of the loan Dataframe
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
# ...

# %%
# The shape of the loan Dataframe
print("Dataset shape:", loan.shape)
# Out:
# Dataset shape: (255347, 18)

# %%
# The columns of the tweet Dataframe
print("\nColumns:", loan.columns.tolist())
# Out:
# Columns: ['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore', 'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm', 'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus', 'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner', 'Default']

# %%
# Verify missing values of the loan Dataframe
print("\nMissing values per column: \n")
print(loan.isna().sum())
# Out:
# Missing values per column:
#
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %%
# Verify duplicated values of the loan Dataframe
print("\nNumber of duplicate rows:", loan.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
loan['Default'].value_counts(normalize = True)
# Out:
# 0    0.883872
# 1    0.116128
# Name: Default, dtype: float64

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# -----------------------------
# Ensure the Images folder exists
# -----------------------------
os.makedirs("Images", exist_ok=True)

# -----------------------------
# Create French labels for Default
# -----------------------------
loan['Default_label_fr'] = loan['Default'].map({
    0: 'Remboursé à temps (Prêt sain)',
    1: 'Défaut de Remboursement (Prêt à risque)'
})

default_counts = loan['Default_label_fr'].value_counts()

# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(8, 8))
colors = ["#2E86AB", "#D9534F"]  # Blue = safe, Red = risky
explode = (0.05, 0.08)  # Separate slices slightly

wedges, texts, autotexts = plt.pie(
    default_counts,
    labels=default_counts.index,
    autopct='%1.1f%%',
    startangle=120,
    colors=colors,
    explode=explode,
    shadow=True,
    textprops={'fontsize': 13, 'fontweight': 'bold', 'color': 'black'},
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)

# ✅ Percentages in black
for autotext in autotexts:
    autotext.set_color('black')
    autotext.set_fontweight('bold')

# 🧭 Elegant title
plt.title(
    "Répartition des prêts selon le statut de remboursement",
    fontsize=18,
    fontweight='bold',
    pad=25
)

# 🟦 Custom mini legend on the left
legend_elements = [
    Patch(facecolor="#2E86AB", edgecolor='white', label='Prêt sain'),
    Patch(facecolor="#D9534F", edgecolor='white', label='Prêt à risque')
]
plt.legend(
    handles=legend_elements,
    # title="Légende",
    title_fontsize=12,
    fontsize=12,
    loc='center left',
    bbox_to_anchor=(-0.25, 0.5),
    frameon=False
)

plt.tight_layout()

# -----------------------------
# Save the plot (HD for presentation)
# -----------------------------
# plt.savefig("../Images/defautpret.png", dpi=300, bbox_inches="tight", facecolor="white")

plt.show()

# %% [markdown]
# Dans l’ensemble, les données montrent une **excellente intégrité et un fort potentiel analytique** pour prédire le risque de défaut de paiement. La prochaine étape consiste à effectuer une **Exploratory Data Analysis (EDA)** pour mieux comprendre les relations entre variables, les distributions et les valeurs aberrantes susceptibles d’influencer la performance prédictive.
#
#
# - **Intégrité des données :**
#   Il n’y a **aucune valeur manquante** et **aucun doublon**, ce qui suggère que le jeu de données est **bien structuré et prêt pour l’analyse**. Cette qualité élevée des données garantit qu’aucune imputation ou reconstruction n’est nécessaire avant l’exploration.
#
# - **Composition des variables :**
#   Le jeu de données inclut des indicateurs financiers clés tels que `Income`, `LoanAmount`, `CreditScore` et `DTIRatio`, ainsi que des variables démographiques et comportementales comme `Education`, `EmploymentType`, `MaritalStatus` et `HasMortgage`.
#   Cette diversité permettra au modèle de capturer à la fois **la capacité financière** et les **comportements personnels** influençant le remboursement des prêts.
#
# - **Analyse de la variable cible :**
#   La variable `Default` révèle un **déséquilibre de classes** — environ **88 % des emprunteurs ont remboursé à temps**, tandis que **12 % ont fait défaut**.
#   Cela correspond au comportement réel des crédits, où la majorité des emprunteurs sont fiables, mais une petite fraction représente un **risque financier plus élevé**.
#   Cependant, ce déséquilibre devra être pris en compte lors de la phase de modélisation afin d’éviter un biais vers la classe majoritaire.

# %% [markdown]
# ## **Data Cleaning (Nettoyage des Données)**
# ---
#
#
# Avant de procéder à l'Analyse Exploratoire des Données (EDA), il est essentiel de **s'assurer que le jeu de données est prêt pour la visualisation et l'analyse**. Bien que notre dataset soit déjà propre—**pas de valeurs manquantes, pas de doublons, et des types de données appropriés**—nous effectuons quelques vérifications pour garantir la qualité et la cohérence :
#
# - **Vérification des types de données :** S'assurer que les colonnes numériques et catégorielles sont correctement identifiées.
# - **Contrôles de cohérence :** Vérifier que les variables catégorielles (par ex., `Education`, `EmploymentType`, `MaritalStatus`) ont des valeurs cohérentes.
# - **Colonnes dérivées pour l'EDA :** Ajouter des labels (comme `Default_label_fr`) pour rendre les visualisations **claires, interprétables et orientées business**.
#
# Cette étape garantit que notre jeu de données est **entièrement prêt à générer des insights et visualisations** pour comprendre les **patterns et facteurs de risque** liés au remboursement des prêts.

# %%
# -----------------------------
# Data Cleaning & Preparation for EDA
# -----------------------------

# 1 Check data types and convert if necessary
print("Data Types:\n", loan.dtypes)

# Example: Ensure categorical columns are 'category' type for better handling
categorical_cols = ['Education', 'EmploymentType', 'MaritalStatus', 
                    'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner']
for col in categorical_cols:
    loan[col] = loan[col].astype('category')

print("\nUpdated Data Types:\n", loan.dtypes)
# Out:
# Data Types:
#  LoanID               object
# Age                   int64
# Income                int64
# LoanAmount            int64
# CreditScore           int64
# MonthsEmployed        int64
# NumCreditLines        int64
# InterestRate        float64
# LoanTerm              int64
# DTIRatio            float64
# Education            object
# EmploymentType       object
# MaritalStatus        object
# HasMortgage          object
# HasDependents        object
# LoanPurpose          object
# HasCoSigner          object
# Default               int64
# Default_label_fr     object
# dtype: object
#
# Updated Data Types:
#  LoanID                object
# Age                    int64
# Income                 int64
# LoanAmount             int64
# CreditScore            int64
# MonthsEmployed         int64
# NumCreditLines         int64
# InterestRate         float64
# LoanTerm               int64
# DTIRatio             float64
# Education           category
# EmploymentType      category
# ...

# %%
# 2️ Consistency check for categorical values
for col in categorical_cols:
    print(f"\nUnique values in {col}:", loan[col].unique())
# Out:
# Unique values in Education: ['Bachelor's', 'Master's', 'High School', 'PhD']
# Categories (4, object): ['Bachelor's', 'Master's', 'High School', 'PhD']
#
# Unique values in EmploymentType: ['Full-time', 'Unemployed', 'Self-employed', 'Part-time']
# Categories (4, object): ['Full-time', 'Unemployed', 'Self-employed', 'Part-time']
#
# Unique values in MaritalStatus: ['Divorced', 'Married', 'Single']
# Categories (3, object): ['Divorced', 'Married', 'Single']
#
# Unique values in HasMortgage: ['Yes', 'No']
# Categories (2, object): ['Yes', 'No']
#
# Unique values in HasDependents: ['Yes', 'No']
# Categories (2, object): ['Yes', 'No']
#
# Unique values in LoanPurpose: ['Other', 'Auto', 'Business', 'Home', 'Education']
# Categories (5, object): ['Other', 'Auto', 'Business', 'Home', 'Education']
#
# Unique values in HasCoSigner: ['Yes', 'No']
# Categories (2, object): ['Yes', 'No']

# %%
# 3️ Verify numerical ranges for sanity
numerical_cols = ['Age', 'Income', 'LoanAmount', 'CreditScore', 
                  'MonthsEmployed', 'NumCreditLines', 'InterestRate', 
                  'LoanTerm', 'DTIRatio']
for col in numerical_cols:
    print(f"{col}: min={loan[col].min()}, max={loan[col].max()}")
# Out:
# Age: min=18, max=69
# Income: min=15000, max=149999
# LoanAmount: min=5000, max=249999
# CreditScore: min=300, max=849
# MonthsEmployed: min=0, max=119
# NumCreditLines: min=1, max=4
# InterestRate: min=2.0, max=25.0
# LoanTerm: min=12, max=60
# DTIRatio: min=0.1, max=0.9

# %% [markdown]
# Loan_to_Income est une variable très pertinente économiquement, car elle capture la solvabilité réelle de l’emprunteur, indépendamment du montant absolu du prêt ou du revenu seul. Elle mesure le poids du prêt par rapport au revenu mensuel ou annuel de l’emprunteur.
#
# Si Loan_to_Income est élevé, alors le client emprunte un montant très important par rapport à ses revenus, il a moins de marge de sécurité ,plus de risque de défaut.
# Tandis que Loan_to_Income est faible, alors le prêt représente une petite proportion de ses revenus, il a plus de capacité à rembourser ,moins de risque.

# %%
# 4️ Create French labels for target variable (for EDA plots)
loan['Default_label_fr'] = loan['Default'].map({
    0: 'Remboursé à Temps (Prêt Sain)',
    1: 'Défaut de Remboursement (Prêt à Risque)'
})

# 5️ (Optional) Create additional derived columns for analysis
# Example: Loan-to-Income ratio
loan['Loan_to_Income'] = loan['LoanAmount'] / loan['Income']

# 6️ Quick verification of changes
print("\nSample of prepared data for EDA:\n" ) 
loan.head()
# loan.shape
# Out:
# Sample of prepared data for EDA:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# ...

# %% [markdown]
# Après ces vérifications et ajustements, le jeu de données est **propre, cohérent et prêt pour l’Analyse Exploratoire des Données (EDA)**.
# Nous pouvons désormais explorer les **patterns, tendances et relations** entre les variables pour mieux comprendre les **facteurs de risque de défaut de prêt**.

# %% [markdown]
# ## **III – Exploratory Data Analysis (EDA)**
# ---
#
# L’Analyse Exploratoire des Données (EDA) vise à **comprendre en profondeur la structure, les distributions et les relations** entre les variables du jeu de données.
# Cette étape permet de **mettre en évidence les facteurs de risque**, d’identifier **les tendances et anomalies**, et de préparer le terrain pour la **modélisation prédictive**.
#
# Dans cette section, nous allons :
# - Visualiser la **répartition des variables numériques et catégorielles**.
# - Identifier les **corrélations et relations importantes** entre les caractéristiques et le statut de remboursement.
# - Extraire des **insights concrets pour le contexte bancaire**, y compris pour des institutions en Haïti.
#
# Comme nous pouvons l’observer sur les graphiques ci-dessous, certaines tendances et différences apparaissent clairement, ce qui nous guidera pour **l’ingénierie des features et le choix des modèles**.

# %% [markdown]
# - ### Visualiser la **répartition des variables catégorielles**

# %% [markdown]
# Avant d’explorer les caractéristiques des emprunteurs, il est important de comprendre la **répartition globale des prêts** dans le portefeuille.
# Comme le montre le graphique ci-dessous, la majorité des prêts (**88,4 %**) sont **remboursés à temps**, ce qui indique que le portefeuille global est relativement sain.
#
# Cependant, un **segment critique de 11,6 %** correspond à des **prêts à risque (défauts de remboursement)**.
# Cette information est essentielle pour les institutions financières, y compris en Haïti, afin de :
# - **Identifier les risques globaux du portefeuille**,
# - **Prioriser les actions de suivi et de prévention**,
# - **Allouer efficacement les ressources pour gérer les défauts potentiels**.
#
# > ⚠️ Référez-vous au graphique ci-dessous pour visualiser la répartition exacte des prêts sains et à risque.

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# -----------------------------
# Ensure the Images folder exists
# -----------------------------
os.makedirs("Images", exist_ok=True)

# -----------------------------
# Create French labels for Default
# -----------------------------
loan['Default_label_fr'] = loan['Default'].map({
    0: 'Remboursé à temps (Prêt sain)',
    1: 'Défaut de remboursement (Prêt à risque)'
})

default_counts = loan['Default_label_fr'].value_counts()
# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(8, 8))
colors = ["#2E86AB", "#D9534F"]  # Blue = safe, Red = risky
explode = (0.05, 0.08)  # Separate slices slightly

wedges, texts, autotexts = plt.pie(
    default_counts,
    labels=default_counts.index,
    autopct='%1.1f%%',
    startangle=120,
    colors=colors,
    explode=explode,
    shadow=True,
    textprops={'fontsize': 13, 'fontweight': 'bold', 'color': 'black'},
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)

# ✅ Percentages in black
for autotext in autotexts:
    autotext.set_color('black')
    autotext.set_fontweight('bold')

# 🧭 Elegant title
plt.title(
    "Répartition des prêts selon le statut de remboursement",
    fontsize=18,
    fontweight='bold',
    pad=25
)

#  Custom mini legend on the left
legend_elements = [
    Patch(facecolor="#2E86AB", edgecolor='white', label='Prêt sain'),
    Patch(facecolor="#D9534F", edgecolor='white', label='Prêt à risque')
]
plt.legend(
    handles=legend_elements,
    # title="Légende",
    title_fontsize=12,
    fontsize=12,
    loc='center left',
    bbox_to_anchor=(-0.25, 0.5),
    frameon=False
)
plt.tight_layout()

# -----------------------------
# Save the plot (HD for presentation)
# -----------------------------
plt.savefig("../Images/defautpret.png", dpi=300, bbox_inches="tight", facecolor="white")

plt.show()

# %% [markdown]
# Avant d’examiner les graphiques ci-dessous, il est utile de noter certaines tendances observables sur les **facteurs démographiques et professionnels** des emprunteurs :
#
# - **Type d’emploi :** Les défauts de remboursement sont légèrement plus élevés chez les **employés à temps partiel (3 %)** et les **travailleurs indépendants (2,9 %)**, tandis que les **employés à temps plein présentent le risque le plus faible (2,4 %)**. Cela suggère que la **stabilité professionnelle** influence fortement la capacité de remboursement.
#
# - **Statut marital :** Les emprunteurs **divorcés (4,2 %)** et **célibataires (4 %)** affichent un risque de défaut plus élevé comparé aux **mariés (3,5 %)**, indiquant que le **soutien familial et financier** peut jouer un rôle dans le comportement de remboursement.
#
# - **Niveau d’éducation :** Les défauts sont légèrement plus fréquents chez ceux avec un **baccalauréat (3,1 %) ou un diplôme secondaire (3,2 %)**, tandis que les **masters (2,7 %) et doctorats (2,6 %)** présentent un risque plus faible. Cela reflète l’influence du **capital humain et des compétences financières** sur la capacité à gérer les obligations de prêt.
#
# - **Autres variables catégorielles :** Les informations sur la possession d’un **prêt hypothécaire**, la présence de **dépendants**, la **finalité du prêt** et la présence d’un **cosignataire** permettent également d’identifier les segments à risque et guider les **décisions stratégiques de crédit**.
#
# > ⚠️ Référez-vous aux graphiques ci-dessous pour visualiser la distribution des prêts à risque selon ces différentes caractéristiques.

# %%
# -----------------------------
# 2️⃣ Analyse des Variables Catégorielles
# -----------------------------
# S'assurer que le dossier Images existe
if not os.path.exists("Images"):
    os.makedirs("Images")

# Créer des labels explicites pour la variable cible
loan['Default_label_fr'] = loan['Default'].map({
    0: 'Remboursé à Temps',
    1: 'Défaut de remboursement'
})

# Liste des variables catégorielles à explorer
categorical_cols = ['Education', 'EmploymentType', 'MaritalStatus', 
                    'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner']

# Boucle sur chaque variable catégorielle
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    
    # Création du graphique
    ax = sns.countplot(
        data=loan, 
        x=col, 
        hue='Default_label_fr',
        palette=["#2E86AB", "#D9534F"],  # Bleu = sain, Rouge = risqué
        edgecolor='black'
    )
    
    # Ajouter les pourcentages sur chaque barre
    total = len(loan)
    for p in ax.patches:
        percentage = f"{100 * p.get_height()/total:.1f}%"
        ax.annotate(
            percentage, 
            (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center', va='bottom', fontsize=11, fontweight='bold', color='black'
        )

    # 🔹 Amélioration du titre et des axes
    plt.title(f"Distribution de {col} selon le Statut du Prêt", fontsize=18, fontweight='bold', pad=15)
    plt.xlabel(col, fontsize=14, fontweight='bold')
    plt.ylabel("Nombre de Prêts", fontsize=14, fontweight='bold')

    # 🔹 Mettre les labels de l’axe X en majuscules et en gras
    ax.set_xticklabels(
        [label.get_text().upper() for label in ax.get_xticklabels()],
        fontsize=12, fontweight='bold'
    )

    # 🔹 Légende claire et concise, avec texte en gras
    legend = plt.legend(
        title='Statut du Prêt',
        title_fontsize=13,
        fontsize=13,
        loc='upper right',
        frameon=True
    )
    plt.setp(legend.get_texts(), fontweight='bold')

    # 🔹 Ajustement final
    plt.xticks(rotation=45)
    plt.tight_layout()

    # 🔹 Sauvegarder chaque graphique automatiquement dans le dossier Images
    filename = f"Images/distribution_{col.lower()}_fr.png"
    plt.savefig(filename, dpi=300, bbox_inches="tight", facecolor="white")

    plt.show()

# %% [markdown]
# - ### Analyse des Variables Numériques : Comprendre les Profils de Risque
#
# Dans cette section, nous analysons la distribution des principales variables numériques **(comme l’âge, le ratio dette/revenu et le ratio prêt/revenu) en fonction du statut de remboursement.**
# L’objectif est d’identifier comment certains indicateurs financiers ou démographiques influencent la probabilité qu’un emprunteur honore ou non ses engagements financiers.
#
# - ***Ces visualisations permettent de repérer des profils de risque et de dégager des tendances comportementales utiles pour le scoring prédictif et la gestion du portefeuille de prêts.***

# %%
# ======================================
# 📊 Analyse des Variables Numériques
# ======================================

import matplotlib.pyplot as plt
import seaborn as sns
import os

# Configuration du style visuel
sns.set(style="whitegrid", palette="muted", font_scale=1.1)

# Liste des colonnes numériques à analyser
numerical_cols = ['Age', 'DTIRatio', 'Loan_to_Income']

# Dossier pour sauvegarder les graphiques
output_dir = "../Images"
os.makedirs(output_dir, exist_ok=True)

# Boucle de visualisation
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    
    # Tracer la distribution avec Seaborn
    sns.histplot(
        data=loan,
        x=col,
        hue='Default_label_fr',
        kde=True,
        bins=30,
        alpha=0.6,
        edgecolor=None
    )

    # Titres et étiquettes en français avec texte en gras
    if col == 'Age':
        plt.title("**Distribution de l’âge selon le statut de remboursement**", fontsize=16, fontweight='bold')
        plt.xlabel("**Âge de l’emprunteur**", fontsize=13, fontweight='bold')
    elif col == 'DTIRatio':
        plt.title("**Ratio Dette/Revenu (DTI) et statut de remboursement**", fontsize=16, fontweight='bold')
        plt.xlabel("**Ratio Dette/Revenu (DTI)**", fontsize=13, fontweight='bold')
    elif col == 'Loan_to_Income':
        plt.title("**Ratio Montant du Prêt / Revenu et statut de remboursement**", fontsize=16, fontweight='bold')
        plt.xlabel("**Ratio Prêt/Revenu**", fontsize=13, fontweight='bold')

    plt.ylabel("**Nombre d’emprunteurs**", fontsize=13, fontweight='bold')
    plt.legend(title="**Statut de remboursement**", loc="upper right")
    plt.tight_layout()

    # Sauvegarde et affichage du graphique
    file_name = f"distribution_{col.lower()}_fr.png"
    save_path = os.path.join(output_dir, file_name)
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

    # print(f"✅ Graphique sauvegardé : {save_path}")

# print("\n📁 Tous les graphiques ont été générés et enregistrés dans le dossier 'Images/'.")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# L’analyse révèle qu’un **ratio prêt/revenu supérieur à 2,5** constitue un **seuil critique de risque**: les emprunteurs dépassant ce niveau affichent une *probabilité de défaut nettement accrue, tandis que ceux situés **entre 0,5 et 2,5** représentent **près de 70 % du portefeuille** et maintiennent un comportement de remboursement stable.
#
# Cette information peut orienter les institutions financières vers une **segmentation du risque plus fine, une politique d’octroi optimisée, et une stratégie de tarification différenciée** pour maximiser la **rentabilité tout en maîtrisant le risque de défaut.**

# %% [markdown]
# - Identifier les **corrélations et relations importantes**

# %%
# 3️⃣ Numerical Features Analysis
# -----------------------------
numerical_cols = ['Age', 'Income', 'LoanAmount', 'CreditScore', 'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm', 'DTIRatio', 'Loan_to_Income']

# %%
# 4️⃣ Correlation Heatmap
# -----------------------------
plt.figure(figsize=(12, 10))

# Create the heatmap
sns.heatmap(
    loan[numerical_cols].corr(),
    annot=True,
    fmt=".2f",
    cmap="RdYlBu_r",  # Balanced color palette for positive/negative correlations
    linewidths=0.5,
    cbar_kws={'label': 'Correlation Coefficient'},
    annot_kws={"size": 12, "fontweight": "bold"}
)

# Title and axis styling
plt.title("🔥 Carte de Corrélation des Variables Numériques 🔥", fontsize=18, fontweight='bold', pad=20)
plt.xticks(rotation=45, ha='right', fontsize=11, fontweight='bold')
plt.yticks(rotation=0, fontsize=11, fontweight='bold')

# Adjust layout for clarity
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### ***Key Insights & Analysis***
# ----
# L’Analyse Exploratoire des Données (EDA) offre une vue complète sur le **comportement de remboursement des prêts** et met en évidence les principaux **facteurs de risque** selon les caractéristiques démographiques, professionnelles et financières des emprunteurs. Les observations ci-dessous sont présentées dans un contexte business, avec des recommandations exploitables pour les parties prenantes, y compris les banques en Haïti ou dans d’autres marchés émergents.
#
# 1. **Performance Globale des Prêts (Diagramme circulaire)**
#    Le diagramme circulaire montre qu’environ **88% des emprunteurs remboursent leurs prêts à temps**, tandis que **12% font défaut**. Même si la majorité des clients sont fiables, ce **segment minoritaire mais critique** représente un **risque financier important** pour les banques. Identifier proactivement ces emprunteurs peut **prévenir des pertes** et stabiliser le portefeuille de prêts.
#
# 2. **Type d’Emploi**
#    Les emprunteurs **indépendants ou à temps partiel** présentent un taux de défaut légèrement supérieur à celui des **employés à temps plein**, indiquant que la **stabilité des revenus** est un facteur clé pour le remboursement. Les banques pourraient en tenir compte lors de l’approbation des prêts ou pour ajuster les taux d’intérêt selon le profil de risque.
#
# 3. **Statut Matrimonial**
#    L’analyse montre que les **divorcés et célibataires** sont plus susceptibles de faire défaut que les personnes **mariées**. Cela suggère que le **soutien familial et la stabilité du foyer** influencent positivement le remboursement. Les stratégies de prêt peuvent intégrer ce facteur pour concevoir des **interventions ciblées**.
#
# 4. **Niveau d’Éducation**
#    Les emprunteurs ayant un niveau d’études **supérieur (Master, PhD)** ont tendance à moins faire défaut que ceux ayant un niveau **Bachelor ou secondaire**, soulignant l’importance de la **littératie financière et du potentiel de revenu** dans la gestion du risque. L’éducation peut servir de **proxy pour la stabilité financière** dans les modèles de scoring.
#
# 5. **Autres Facteurs Catégoriels**
#    Des variables comme **propriétaire d’une hypothèque, nombre de personnes à charge, objectif du prêt ou présence d’un co-emprunteur** fournissent également des informations précieuses. Par exemple, un co-emprunteur ou une expérience hypothécaire antérieure est généralement associé à une **meilleure fiabilité de remboursement**, mettant en avant l’importance des **antécédents financiers et de la garantie sociale**.
#
# **Principaux enseignements pour les décideurs :**
# - Bien que le taux de défaut soit relativement faible, l’**impact financier des défauts reste significatif**, et une surveillance proactive est essentielle.
# - Le **type d’emploi, le statut matrimonial et le niveau d’éducation** sont des prédicteurs pertinents pour évaluer le risque et guider des **politiques de crédit ciblées**.
# - Ces insights permettent aux banques de concevoir des **stratégies de prêt adaptées au risque**, de développer des **mesures préventives pour les emprunteurs à risque** et d’améliorer la **stabilité globale du portefeuille**.
#
# > L’EDA fournit une base solide pour le **feature engineering et le modeling prédictif**. Comprendre ces patterns permet aux institutions financières de mettre en place des **stratégies basées sur les données** pour réduire les défauts tout en favorisant un prêt responsable.
